# %% [markdown]
# # Exploring the UTx000 Dataset
# From the first cohort in Spring 2020

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Beacon Summary
# This dataset was more or less a trial run, but some of these data could be useful. We need to look at what kind of data the beacons recovered.

# %%
import os

import pandas as pd
import numpy as np

from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import seaborn as sns

import scipy

# %% [markdown]
# # Data Import

# %%
beacon_data = pd.read_csv('../data/processed/bpeace1-beacon.csv',
                     index_col=0,parse_dates=True,infer_datetime_format=True)
beacon_data.head()
# Out:
#                      TVOC  eCO2  Lux  Visible  Infrared  NO2  T_NO2  RH_NO2  \
# Timestamp
# 2020-01-13 00:00:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-01-13 00:05:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-01-13 00:10:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-01-13 00:15:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-01-13 00:20:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
#
#                      CO  T_CO  ...  PM_N_10  PM_C_1  PM_C_2p5  PM_C_4  \
# Timestamp                      ...
# 2020-01-13 00:00:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-01-13 00:05:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-01-13 00:10:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-01-13 00:15:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-01-13 00:20:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
#
#                      PM_C_10   z  Beacon     Beiwe          Fitbit  REDCap
# Timestamp
# 2020-01-13 00:00:00      NaN NaN      29  cjbncgvw  20200110045001     162
# 2020-01-13 00:05:00      NaN NaN      29  cjbncgvw  20200110045001     162
# 2020-01-13 00:10:00      NaN NaN      29  cjbncgvw  20200110045001     162
# 2020-01-13 00:15:00      NaN NaN      29  cjbncgvw  20200110045001     162
# 2020-01-13 00:20:00      NaN NaN      29  cjbncgvw  20200110045001     162
#
# [5 rows x 28 columns]

# %% [markdown]
# # Raw Data Inspection
# Here we do some simple visualizations to check out how much data we have available.

# %% [markdown]
# ## Heatmap
# A heatmap gives us a nice visual representation of any data gaps.

# %%
var_list = ['PM_C_2p5','CO2','CO','NO2','T_NO2','Lux']
limit_list = [[1,75],[1,2000],[1,20],[1,100],[1,50],[0,600000]]
for variable, limits in zip(var_list, limit_list):
    print(f'Working for {variable}')
    heatmap_df = pd.DataFrame()
    for beacon in beacon_data['Beacon'].unique():
        if beacon not in [7,9,11,10,12,14,15,16,17,18,19,20]:
            data_by_beacon = beacon_data[beacon_data['Beacon'] == beacon]
            data_by_beacon = data_by_beacon[data_by_beacon[variable] > 1]
            data_by_beacon = data_by_beacon.resample('1h').mean()
            heatmap_df = pd.concat([heatmap_df,data_by_beacon[variable]],axis=1)
            heatmap_df.rename(columns={variable:beacon}, inplace=True)

    print(f'\tData collected')
    fig, ax = plt.subplots(figsize=(20,15))
    df_to_plot = heatmap_df.T
    print(f'\tPlotting')
    sns.heatmap(df_to_plot,vmin=np.nanmin(df_to_plot),vmax=np.nanmax(df_to_plot))
    
    plt.show()
    plt.close()
# Out:
# Working for PM_C_2p5
# 	Data collected
# 	Plotting
# Working for CO2
# 	Data collected
# 	Plotting
# Working for CO
# 	Data collected
# 	Plotting
# Working for NO2
# 	Data collected
# 	Plotting
# Working for T_NO2
# 	Data collected
# 	Plotting
# Working for Lux
# 	Data collected
# 	Plotting
