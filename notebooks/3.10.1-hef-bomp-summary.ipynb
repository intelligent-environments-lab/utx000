# %% [markdown]
# # Ambient Particulate Matter on Campus
# Exploring the data collected by the Bleed Orange, Measure Purple Campaign

# %%
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Summarizing Particulate Matter on Campus
# Just want to get a sense of what is happening on campus.

# %%
import os
import sys
sys.path.append('../')

from src.visualization import visualize
from src.data import bomp_data_processer

import pandas as pd
pd.set_option('display.max_columns', 200)
import numpy as np

from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

from scipy import stats

# %% [markdown]
# # Data Import
# We have only one dataset to import from the bleed-orange-measure-purple project.

# %%
data_a = bomp_data_processer.import_raw(datetime(2019,1,1),datetime(2020,6,1),data_dir="../../bleed-orange-measure-purple/data/raw/purpleair/")
#data_b = bomp_data_processer.import_raw(datetime(2019,1,1),datetime(2019,6,1),data_dir="../../bleed-orange-measure-purple/data/raw/purpleair/B/")
# Out:
# filename: B - list index out of range

# %% [markdown]
# # Visualizing

# %%
fig, ax = plt.subplots(figsize=(24,8))
for pa in data_a["device"].unique():
    ax.scatter(data_a[data_a["device"] == pa]["timestamp"],data_a[data_a["device"] == pa]["pm2p5_mass"],lw=2,label=pa)
    
plt.show()
plt.close()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# Looks like there isn't any overlap with the UTx000 data and the BOMP data which is very frustrating.
#
# </div>
