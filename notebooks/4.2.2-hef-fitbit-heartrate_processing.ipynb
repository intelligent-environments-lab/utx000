# %% [markdown]
# # Fitbit Exploration
# For an explanation on the variables, take a look at the [data dictionary created by Fitabase](https://www.fitabase.com/media/1546/fitabasedatadictionary.pdf).

# %% [markdown]
# ## Heart Rate Processing
# This notebook is concerned with looking at and processing the heart rate data provided by Fitbit.

# %%
import os
import sys
sys.path.append('../')

from src.features import build_features
from src.visualization import visualize
from src.reports import make_report

import pandas as pd
import numpy as np

from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# %% [markdown]
# ## Importing Data
# We have a function defined in 4.2.0 for importing Fitbit intra-day data

# %%
def import_fitbit(filename, pt_dir=f"/Volumes/HEF_Dissertation_Research/utx000/extension/data/fitbit/"):
    '''
    
    '''
    print(f"\tReading from file {filename}")
    df = pd.DataFrame()
    for pt in os.listdir(pt_dir):
        if pt[0] != ".":
            print(f"\t\tReading for participant {pt}")
            try:
                temp = pd.read_csv(f"{pt_dir}{pt}/fitbit_{filename}.csv", index_col=0, parse_dates=True)
                if filename[:4] == "intr":
                    temp = process_fitbit_intraday(temp)
                
                temp["beiwe"] = pt
                df = df.append(temp)
            except FileNotFoundError:
                print(f"\t\tFile {filename} not found for participant {pt}")
                
    return df

# %%
def process_fitbit_intraday(raw_df,resample_rate=1):
    '''
    
    '''
    try:
        df = raw_df.resample(f'{resample_rate}T').mean()
    except TypeError:
        print(f"\t\tDataframe is most likely empty ({len(raw_df)})")
        return raw_df
    return df

# %% [markdown]
# The initial function resampled the data from every hour, but that is too coarse of a resolution to see the heart rate data so I have changed it to 1-minute. I have also decided to combine the ```process_fitbit_intraday``` into the ```import_fitbit``` function so that the resample rate can be a direct input.

# %%
def import_fitbit(filename, pt_dir=f"/Volumes/HEF_Dissertation_Research/utx000/extension/data/fitbit/", resample_rate=60):
    '''
    
    '''
    print(f"\tReading from file {filename}")
    df = pd.DataFrame()
    for pt in os.listdir(pt_dir):
        if pt[0] != ".":
            print(f"\t\tReading for participant {pt}")
            try:
                temp = pd.read_csv(f"{pt_dir}{pt}/fitbit_{filename}.csv", index_col=0, parse_dates=True)
                if filename[:4] == "intr":
                    try:
                        temp = temp.resample(f'{resample_rate}T').mean()
                    except TypeError:
                        print(f"\t\tDataframe is most likely empty ({len(temp)})")
                
                temp["beiwe"] = pt
                df = df.append(temp)
            except FileNotFoundError:
                print(f"\t\tFile {filename} not found for participant {pt}")
                
    return df

# %%
fitbit_intra = import_fitbit("intraday_records")
# Out:
# 	Reading from file intraday_records
# 		Reading for participant 15tejjtw
# 		Reading for participant 1a9udoc5
# 		Reading for participant 1isvt8z8
# 		Dataframe is most likely empty (0)
# 		Reading for participant 28up4c3g
# 		Dataframe is most likely empty (0)
# 		Reading for participant 2vj84fjp
# 		Dataframe is most likely empty (0)
# 		Reading for participant 2vs5x6x9
# 		Dataframe is most likely empty (0)
# 		Reading for participant 2xtqkfz1
# 		Reading for participant 34483b37
# 		Dataframe is most likely empty (0)
# 		Reading for participant 3k5hntn3
# 		Dataframe is most likely empty (0)
# 		Reading for participant 3mf868h9
# 		Dataframe is most likely empty (0)
# 		Reading for participant 3muzh3ip
# 		Dataframe is most likely empty (0)
# 		Reading for participant 42epayem
# 		Dataframe is most likely empty (0)
# 		Reading for participant 4i7679py
# 		Reading for participant 5bg4j1pp
# 		Dataframe is most likely empty (0)
# 		Reading for participant 5fvmg226
# 		File intraday_records not found for participant 5fvmg226
# 		Reading for participant 745vq78e
# 		Reading for participant 76w6lc1e
# 		Dataframe is most likely empty (0)
# 		Reading for participant 789gcb6u
# 		File intraday_records not found for participant 789gcb6u
# 		Reading for participant 7dhu3pn7
# 		Reading for participant 7esq1z48
# 		Dataframe is most likely empty (0)
# 		Reading for participant 8km1l6ms
# 		Dataframe is most likely empty (0)
# 		Reading for participant 9h8gt1q6
# 		Dataframe is most likely empty (0)
# 		Reading for participant 9jtzsuu8
# 		Reading for participant 9q1adgjk
# 		Reading for participant 9xmhtq74
# 		File intraday_records not found for participant 9xmhtq74
# 		Reading for participant 9y45ufjy
# 		Dataframe is most likely empty (0)
# 		Reading for participant a72ljpy4
# 		Dataframe is most likely empty (0)
# 		Reading for participant adv5yxrq
# 		Dataframe is most likely empty (0)
# 		Reading for participant amrqgbar
# 		Dataframe is most likely empty (0)
# 		Reading for participant awa8uces
# 		Reading for participant axk49ssu
# 		Reading for participant bc1z575j
# 		Dataframe is most likely empty (0)
# 		Reading for participant bjhpm88s
# 		Dataframe is most likely empty (0)
# 		Reading for participant bl3h5apm
# 		Dataframe is most likely empty (0)
# 		Reading for participant cnpj2xu4
# 		Dataframe is most likely empty (0)
# 		Reading for participant d5qxvm2x
# 		Dataframe is most likely empty (0)
# 		Reading for participant d9x9hdc3
# 		Dataframe is most likely empty (0)
# 		Reading for participant dv7kt6ue
# 		Dataframe is most likely empty (0)
# 		Reading for participant e73a1pd5
# 		Reading for participant e8js2jdf
# 		Reading for participant egbyyyeo
# 		Dataframe is most likely empty (0)
# 		Reading for participant ewvz3zm1
# 		Reading for participant eyf8oqwl
# 		Reading for participant fjor6fof
# 		Dataframe is most likely empty (0)
# 		Reading for participant gccj6zrv
# 		Dataframe is most likely empty (0)
# 		Reading for participant gu5qletd
# 		Dataframe is most likely empty (0)
# 		Reading for participant h8aoiyhv
# 		Reading for participant hcpu5myv
# 		Reading for participant hfttkth7
# 		Reading for participant hrqrneay
# 		Dataframe is most likely empty (0)
# 		Reading for participant hxj6brwj
# 		Reading for participant i4w8dx6l
# 		Reading for participant idbkjh8u
# 		Reading for participant ijz9gssj
# 		Dataframe is most likely empty (0)
# 		Reading for participant itmylz3g
# 		Reading for participant itn82o6p
# 		Dataframe is most likely empty (0)
# 		Reading for participant lkkjddam
# 		Reading for participant loxhw1gk
# 		Dataframe is most likely empty (0)
# 		Reading for participant mm69prai
# 		Reading for participant mv14b8aj
# 		Dataframe is most likely empty (0)
# 		Reading for participant nmmo2594
# 		Dataframe is most likely empty (0)
# 		Reading for participant nonlw2g8
# 		Dataframe is most likely empty (0)
# 		Reading for participant nvtfpaor
# 		Reading for participant obb7z8jm
# 		Dataframe is most likely empty (0)
# 		Reading for participant oxcpr7e3
# 		Reading for participant pfsvsd9j
# 		Dataframe is most likely empty (0)
# 		Reading for participant phdiu7p3
# 		Dataframe is most likely empty (0)
# 		Reading for participant q5y11ytm
# 		Dataframe is most likely empty (0)
# 		Reading for participant qpro16vm
# 		Dataframe is most likely empty (0)
# 		Reading for participant r11k6uxz
# 		Reading for participant rj4lxgvp
# 		Dataframe is most likely empty (0)
# 		Reading for participant rnse61g4
# 		Reading for participant rvhdl2la
# 		File intraday_records not found for participant rvhdl2la
# 		Reading for participant shi1ykro
# 		Dataframe is most likely empty (0)
# 		Reading for participant t4jphih6
# 		Reading for participant tfhg94sp
# 		Dataframe is most likely empty (0)
# 		Reading for participant tlmlq19s
# 		Reading for participant tmexej5v
# 		Reading for participant u5wdcmwh
# 		Dataframe is most likely empty (0)
# 		Reading for participant uu6knbbx
# 		Dataframe is most likely empty (0)
# 		Reading for participant uz52kilo
# 		Dataframe is most likely empty (0)
# 		Reading for participant vdtyoovh
# 		Dataframe is most likely empty (0)
# 		Reading for participant vpy1a985
# 		Reading for participant vr9j5rry
# 		Reading for participant wlwwibi7
# 		Dataframe is most likely empty (0)
# 		Reading for participant wnprz3dq
# 		Reading for participant xdbdrk6e
# 		Reading for participant xlw5ntd5
# 		Reading for participant xxvnhauv
# 		Dataframe is most likely empty (0)
# 		Reading for participant y1tvkx14
# 		Reading for participant zdpffrox

# %%
fitbit_intra.head()
# Out:
#                      activities_calories  activities_steps  \
# date
# 2020-05-01 00:00:00             1.074652         11.333333
# 2020-05-01 01:00:00             1.101026          5.500000
# 2020-05-01 02:00:00             0.959310               NaN
# 2020-05-01 03:00:00             0.959310               NaN
# 2020-05-01 04:00:00             1.148265          8.000000
#
#                      activities_distance  activities_heart     beiwe
# date
# 2020-05-01 00:00:00             0.004536         65.960829  15tejjtw
# 2020-05-01 01:00:00             0.002175         64.045783  15tejjtw
# 2020-05-01 02:00:00                  NaN         62.728090  15tejjtw
# 2020-05-01 03:00:00                  NaN         61.418224  15tejjtw
# 2020-05-01 04:00:00             0.003169         64.459794  15tejjtw

# %%
print(f'Number of datapoints: {len(fitbit_intra)}')
# Out:
# Number of datapoints: 91637

# %% [markdown]
# ## Individual Participant Checks
# There are a few participants that wore their Fitbit 100% of the time. Here we check them against their heart rate.

# %% [markdown]
# ### r11k6uxz
# Based on the activity minutes, this participant wore their Fitbit the ENTIRE time without having to charge it? We can check that.

# %%
pt = 'r11k6uxz'
fb_intra_pt = fitbit_intra[fitbit_intra['beiwe'] == pt]
print(f'Number of datapoints: {len(fb_intra_pt)}')
# checking NaN values
n_nans = fb_intra_pt['activities_heart'].isna().sum()
print(f'NaN Values: {n_nans}')
# Out:
# Number of datapoints: 158
# NaN Values: 1

# %%
fb_intra_pt.head()
# Out:
#                      activities_calories  activities_steps  \
# date
# 2020-07-12 12:30:00              1.70378               NaN
# 2020-07-12 12:31:00              1.70378               NaN
# 2020-07-12 12:32:00              4.98028              47.0
# 2020-07-12 12:33:00              4.19392              24.0
# 2020-07-12 12:34:00              4.19392              23.0
#
#                      activities_distance  activities_heart     beiwe
# date
# 2020-07-12 12:30:00                  NaN         78.285714  r11k6uxz
# 2020-07-12 12:31:00                  NaN         86.125000  r11k6uxz
# 2020-07-12 12:32:00             0.022059         91.833333  r11k6uxz
# 2020-07-12 12:33:00             0.011247         87.900000  r11k6uxz
# 2020-07-12 12:34:00             0.010750         88.428571  r11k6uxz

# %%
fig, ax = plt.subplots()
ax.hist(fb_intra_pt['activities_heart'],bins=100)

plt.show()
plt.close()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
fix, ax = plt.subplots(figsize=(16,6))
ax.plot(fb_intra_pt.index,fb_intra_pt['activities_heart'])
plt.show()
plt.close()

# %% [markdown]
# Somehow this participant has nearly no heart rate data, even though the activity was complete the entire time. We need to investigate this participant's daily data to see what the issue is.

# %%
daily = pd.read_csv("../data/processed/bpeace2-fitbit-daily.csv",index_col=0,parse_dates=True)
daily_pt = daily[daily['beiwe'] == pt]
#daily_pt["activities_minutes"] = daily_pt[["activities_minutesSedentary","activities_minutesLightlyActive",
                                               # "activities_minutesFairlyActive","activities_minutesVeryActive"]].sum(axis=1)
daily_pt[:10]
# Out:
#             activities_calories  activities_caloriesBMR  activities_steps  \
# date
# 2020-05-01               1887.0                  1887.0                 0
# 2020-05-02               1887.0                  1887.0                 0
# 2020-05-03               1887.0                  1887.0                 0
# 2020-05-04               1887.0                  1887.0                 0
# 2020-05-05               1887.0                  1887.0                 0
# 2020-05-06               1887.0                  1887.0                 0
# 2020-05-07               1887.0                  1887.0                 0
# 2020-05-08               1887.0                  1887.0                 0
# 2020-05-09               1887.0                  1887.0                 0
# 2020-05-10               1887.0                  1887.0                 0
#
#             activities_distance  activities_minutesSedentary  \
# date
# 2020-05-01                  0.0                         1440
# 2020-05-02                  0.0                         1440
# 2020-05-03                  0.0                         1440
# 2020-05-04                  0.0                         1440
# 2020-05-05                  0.0                         1440
# 2020-05-06                  0.0                         1440
# 2020-05-07                  0.0                         1440
# 2020-05-08                  0.0                         1440
# 2020-05-09                  0.0                         1440
# 2020-05-10                  0.0                         1440
#
#             activities_minutesLightlyActive  activities_minutesFairlyActive  \
# date
# 2020-05-01                                0                               0
# 2020-05-02                                0                               0
# 2020-05-03                                0                               0
# 2020-05-04                                0                               0
# 2020-05-05                                0                               0
# 2020-05-06                                0                               0
# 2020-05-07                                0                               0
# 2020-05-08                                0                               0
# 2020-05-09                                0                               0
# 2020-05-10                                0                               0
#
#             activities_minutesVeryActive  activities_activityCalories  \
# date
# 2020-05-01                             0                          0.0
# 2020-05-02                             0                          0.0
# 2020-05-03                             0                          0.0
# 2020-05-04                             0                          0.0
# 2020-05-05                             0                          0.0
# 2020-05-06                             0                          0.0
# 2020-05-07                             0                          0.0
# 2020-05-08                             0                          0.0
# 2020-05-09                             0                          0.0
# 2020-05-10                             0                          0.0
#
#              body_bmi  body_fat  body_weight  foods_log_caloriesIn  \
# date
# 2020-05-01  25.333595       0.0        185.0                   0.0
# 2020-05-02  25.333595       0.0        185.0                   0.0
# 2020-05-03  25.333595       0.0        185.0                   0.0
# 2020-05-04  25.333595       0.0        185.0                   0.0
# 2020-05-05  25.333595       0.0        185.0                   0.0
# 2020-05-06  25.333595       0.0        185.0                   0.0
# 2020-05-07  25.333595       0.0        185.0                   0.0
# 2020-05-08  25.333595       0.0        185.0                   0.0
# 2020-05-09  25.333595       0.0        185.0                   0.0
# 2020-05-10  25.333595       0.0        185.0                   0.0
#
#             foods_log_water     beiwe
# date
# 2020-05-01              0.0  r11k6uxz
# 2020-05-02              0.0  r11k6uxz
# 2020-05-03              0.0  r11k6uxz
# 2020-05-04              0.0  r11k6uxz
# 2020-05-05              0.0  r11k6uxz
# 2020-05-06              0.0  r11k6uxz
# 2020-05-07              0.0  r11k6uxz
# 2020-05-08              0.0  r11k6uxz
# 2020-05-09              0.0  r11k6uxz
# 2020-05-10              0.0  r11k6uxz

# %% [markdown]
# ### 2xtqkfz1
# This participant is similar to the above except for maybe two days that were not 100%

# %%
pt = '2xtqkfz1'
fb_intra_pt = fitbit_intra[fitbit_intra['beiwe'] == pt]
print(f'Number of datapoints: {len(fb_intra_pt)}')
# checking NaN values
n_nans = fb_intra_pt['activities_heart'].isna().sum()
print(f'NaN Values: {n_nans}')
# Out:
# Number of datapoints: 82545
# NaN Values: 66490

# %%
fig, ax = plt.subplots()
ax.hist(fb_intra_pt['activities_heart'],bins=100)

plt.show()
plt.close()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
fix, ax = plt.subplots(figsize=(16,6))
ax.plot(fb_intra_pt.index,fb_intra_pt['activities_heart'])
plt.show()
plt.close()

# %% [markdown]
# There are noticeable gaps here that are not present when considering the activity minutes. In fact, the data don't even extend to the end of study period.
