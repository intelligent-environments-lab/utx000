# %% [markdown]
# # IAQ and Survey Response Analysis
# Exploring the relationship between the categorical survey responses and the IAQ measurements.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## IAQ Distributions per Restfulness Score Reportings
# Here we look at the distributions of IAQ measurements for each of the four ratings of restfulness.

# %%
import os
import sys
sys.path.append('../')

from src.features import build_features
from src.visualization import visualize
from src.reports import make_report

import pandas as pd
import numpy as np

from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

import statsmodels.api as sm

# %% [markdown]
# ## Data Import
# We will need just the morning survey results and the beacon data.

# %% [markdown]
# ### Morning EMAs

# %%
ema = pd.read_csv('../data/processed/bpeace2-morning-survey.csv',index_col=0,parse_dates=True,infer_datetime_format=True)
ema.head()
# Out:
#                            ID  Content  Stress  Lonely  Sad  Energy  TST  \
# 2020-07-31 09:25:41  hfttkth7      1.0     2.0     1.0  3.0     0.0  6.0
# 2020-08-19 22:49:04  hfttkth7      1.0     1.0     0.0  1.0     2.0  7.0
# 2020-08-23 10:58:26  hfttkth7      1.0     1.0     1.0  2.0     0.0  6.0
# 2020-07-17 09:52:16  hfttkth7      1.0     1.0     0.0  1.0     2.0  7.0
# 2020-08-12 12:32:54  hfttkth7      1.0     3.0     1.0  2.0     2.0  6.0
#
#                       SOL  NAW  Restful
# 2020-07-31 09:25:41  10.0  3.0      0.0
# 2020-08-19 22:49:04  20.0  1.0      1.0
# 2020-08-23 10:58:26  25.0  0.0      0.0
# 2020-07-17 09:52:16  20.0  3.0      2.0
# 2020-08-12 12:32:54  20.0  0.0      1.0

# %% [markdown]
# ### Beacon IAQ

# %%
beacon = pd.read_csv('../data/processed/bpeace2-beacon.csv',index_col=0,parse_dates=True)
beacon.head()
# Out:
#                      TVOC  eCO2  Lux  Visible  Infrared  NO2  T_NO2  RH_NO2  \
# Timestamp
# 2020-06-11 00:00:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-06-11 00:05:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-06-11 00:10:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-06-11 00:15:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
# 2020-06-11 00:20:00   NaN   NaN  NaN      NaN       NaN  NaN    NaN     NaN
#
#                      CO  T_CO  ...  PM_N_10  PM_C_1  PM_C_2p5  PM_C_4  \
# Timestamp                      ...
# 2020-06-11 00:00:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-06-11 00:05:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-06-11 00:10:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-06-11 00:15:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
# 2020-06-11 00:20:00 NaN   NaN  ...      NaN     NaN       NaN     NaN
#
#                      PM_C_10   z  Beacon     Beiwe  Fitbit  REDCap
# Timestamp
# 2020-06-11 00:00:00      NaN NaN      30  idbkjh8u      22       4
# 2020-06-11 00:05:00      NaN NaN      30  idbkjh8u      22       4
# 2020-06-11 00:10:00      NaN NaN      30  idbkjh8u      22       4
# 2020-06-11 00:15:00      NaN NaN      30  idbkjh8u      22       4
# 2020-06-11 00:20:00      NaN NaN      30  idbkjh8u      22       4
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Getting IAQ measurements for sleep survey responses
# We have to cut the beacon data down to nights that preceded when participants responded to surveys distributed that next morning. This process is slightly different from the one where we cut the beacon data down based on the Fitbit night recordings since there might be a few mornings when participants submitted a survey but did not wear their Fitbit to bed. However, even if there are a few of these instances we cannot summarize the preceding night's IAQ measurements because we don't know when the participant was asleep. Therefore, we **CAN** use the Fitbit-reduced IAQ data as a starting point.

# %%
evening_iaq = pd.read_csv('../data/processed/bpeace2-fitbit-beacon-iaq-evening-full.csv',
                          index_col=0,parse_dates=['Timestamp','start_time','end_time'],infer_datetime_format=True)
evening_iaq.head()
# Out:
#                            TVOC    eCO2     Lux  Visible  Infrared  NO2  \
# Timestamp
# 2020-07-03 06:20:00  192.840000  405.36  0.0000     0.00       0.0  NaN
# 2020-07-03 06:25:00  178.866667  400.00  0.0000     0.00       0.0  NaN
# 2020-07-03 06:30:00  188.760000  401.40  0.9792     0.48       0.0  NaN
# 2020-07-03 06:35:00  193.840000  406.04  2.0400     1.00       0.0  NaN
# 2020-07-03 06:40:00  198.840000  409.44  2.0400     1.00       0.0  NaN
#
#                      T_NO2     RH_NO2       CO  T_CO  ...     PM_C_4  \
# Timestamp                                             ...
# 2020-07-03 06:20:00   27.0  53.400000 -0.47992   NaN  ...  16.400084
# 2020-07-03 06:25:00   27.0  52.833333 -0.30360   NaN  ...  20.737945
# 2020-07-03 06:30:00   27.0  53.000000 -0.22436   NaN  ...  16.946462
# 2020-07-03 06:35:00   27.0  53.000000 -0.26328   NaN  ...  16.101073
# 2020-07-03 06:40:00   27.0  53.000000 -0.40936   NaN  ...  19.142773
#
#                        PM_C_10         z  Beacon     Beiwe  Fitbit  REDCap  \
# Timestamp
# 2020-07-03 06:20:00  16.604594  0.162959      44  4i7679py      38      37
# 2020-07-03 06:25:00  21.006936  0.088227      44  4i7679py      38      37
# 2020-07-03 06:30:00  17.167753  0.114067      44  4i7679py      38      37
# 2020-07-03 06:35:00  16.309091  0.149835      44  4i7679py      38      37
# 2020-07-03 06:40:00  19.383442  0.163325      44  4i7679py      38      37
#
#                              start_time            end_time     beiwe
# Timestamp
# 2020-07-03 06:20:00 2020-07-03 06:20:00 2020-07-03 16:10:00  4i7679py
# 2020-07-03 06:25:00 2020-07-03 06:20:00 2020-07-03 16:10:00  4i7679py
# 2020-07-03 06:30:00 2020-07-03 06:20:00 2020-07-03 16:10:00  4i7679py
# 2020-07-03 06:35:00 2020-07-03 06:20:00 2020-07-03 16:10:00  4i7679py
# 2020-07-03 06:40:00 2020-07-03 06:20:00 2020-07-03 16:10:00  4i7679py
#
# [5 rows x 31 columns]

# %% [markdown]
# Now we compare the sleep survey submission date to the end time of the sleep period for each participant and remove the nights that don't line up

# %%
survey_iaq = pd.DataFrame()
for pt in evening_iaq['Beiwe'].unique():
    # getting pt-specific dfs
    evening_iaq_pt = evening_iaq[evening_iaq['Beiwe'] == pt]
    ema_pt = ema[ema['ID'] == pt]
    survey_dates = ema_pt.index.date
    survey_only_iaq = evening_iaq_pt[evening_iaq_pt['end_time'].dt.date.isin(survey_dates)]
    
    survey_iaq = survey_iaq.append(survey_only_iaq)

# %% [markdown]
# Now we see how many nights we lost:

# %%
print(f'Number of Fitbit-Restricted Points: {len(evening_iaq)}')
print(f'Number of Fitbit- and EMA-Restricted Points: {len(survey_iaq)}')
# Out:
# Number of Fitbit-Restricted Points: 69611
# Number of Fitbit- and EMA-Restricted Points: 30572

# %% [markdown]
# Might as well save this to the processed directory since it could come into use:

# %%
survey_iaq.to_csv('../data/processed/bpeace2-fitbit-beacon-iaq-evening-restricted.csv')

# %% [markdown]
# Now we have the measurements for nights when participants submitted surveys and the final piece is to include the restfulness scores for those evenings.
