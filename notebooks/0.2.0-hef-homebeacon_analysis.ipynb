# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
b7 = pd.DataFrame()
for file in os.listdir('/Users/hagenfritz/Projects/utx000/data/raw/bpeace2/beacon/B07/sensirion/'):
    temp = pd.read_csv(f'/Users/hagenfritz/Projects/utx000/data/raw/bpeace2/beacon/B07/sensirion/{file}',
                      index_col=0,parse_dates=True,infer_datetime_format=True)
    b7 = pd.concat([b7,temp])
    
b7 = b7.resample('5T').mean()

# %%
b7
# Out:
#                      Temperature [C]  Relative Humidity          CO2  \
# Timestamp
# 2020-04-24 16:55:00        30.704353          41.371460   981.018555
# 2020-04-24 17:00:00        30.672524          41.156738   904.951980
# 2020-04-24 17:05:00        30.654794          41.452576   940.362192
# 2020-04-24 17:10:00        30.889892          40.763245  1065.721030
# 2020-04-24 17:15:00        30.326024          39.869873  1132.694028
# ...                              ...                ...          ...
# 2020-06-21 09:55:00        30.463921          37.480713   635.054980
# 2020-06-21 10:00:00        30.540718          37.797302   624.409541
# 2020-06-21 10:05:00        30.601067          38.056091   633.226912
# 2020-06-21 10:10:00        30.734371          38.138977   627.550930
# 2020-06-21 10:15:00        30.764039          38.331985   627.571384
#
#                       PM_N_0p5     PM_N_1    PM_N_2p5      PM_N_4     PM_N_10  \
# Timestamp
# 2020-04-24 16:55:00  68.575893  98.572908  110.168506  111.583270  111.796266
# 2020-04-24 17:00:00  65.060471  86.430438   93.414708   94.258698   94.386353
# 2020-04-24 17:05:00  65.243225  83.373729   88.508077   89.122542   89.215921
# 2020-04-24 17:10:00  68.287109  88.693402   94.877505   95.621135   95.733880
# 2020-04-24 17:15:00  62.020513  85.028264   93.179956   94.169794   94.319159
# ...                        ...        ...         ...         ...         ...
# 2020-06-21 09:55:00   5.947693  11.274791   13.824752   14.139005   14.186086
# 2020-06-21 10:00:00   6.980929  12.239906   14.669890   14.968906   15.013738
# 2020-06-21 10:05:00  10.022245  15.751680   18.208693   18.510018   18.555270
# 2020-06-21 10:10:00   9.047137  15.677280   18.721449   19.095938   19.152094
# 2020-06-21 10:15:00   7.418360  11.836651   13.755837   13.991344   14.026701
#
#                         PM_C_1   PM_C_2p5     PM_C_4    PM_C_10
# Timestamp
# 2020-04-24 16:55:00  14.034913  25.247604  33.081139  33.406196
# 2020-04-24 17:00:00  11.713181  18.517018  23.181152  23.374692
# 2020-04-24 17:05:00  11.000362  16.038871  19.427910  19.568540
# 2020-04-24 17:10:00  11.836755  17.883666  21.989091  22.159450
# 2020-04-24 17:15:00  11.761712  19.673408  25.148882  25.376089
# ...                        ...        ...        ...        ...
# 2020-06-21 09:55:00   1.833241   4.279699   6.023176   6.095523
# 2020-06-21 10:00:00   1.927161   4.261286   5.919738   5.988556
# 2020-06-21 10:05:00   2.355258   4.721609   6.391751   6.461054
# 2020-06-21 10:10:00   2.455662   5.380381   7.457323   7.543507
# 2020-06-21 10:15:00   1.783437   3.630939   4.936431   4.990603
#
# [16625 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(figsize=(16,8))
#b7_short = b7[datetime(2020,6,10):datetime(2020,6,11)]
ax.plot(b7.index,b7['CO2'])
ax.plot(b7.index,b7['PM_C_2p5']*10)

plt.show()
plt.close()
