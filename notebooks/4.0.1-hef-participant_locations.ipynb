# %% [markdown]
# # Participant Locations
# Looking at where the participants were during the UTx000 study.

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', 200)
import numpy as np

from datetime import datetime, timedelta

# %% [markdown]
# # Participant Information

# %%
info = pd.read_excel("../data/raw/utx000/admin/s20c2_participant_list.xlsx",sheet_name="Complete")
info.dropna(subset=["Address"],inplace=True)
info.reset_index(inplace=True)
info = info[["Beiwe ID","First","Last","Address"]]
info[:15]
# Out:
#     Beiwe ID      First       Last  \
# 0   y1tvkx14      Aaron   Alterman
# 1   pgvvwyvh      Aaron      Wheat
# 2   idbkjh8u      Alana   Martinez
# 3   eyf8oqwl  Alexander       Chan
# 4   789gcb6u    Adriana     Banchs
# 5   kyj367pi     Angela   Gordillo
# 6   lkkjddam    Austin     Reynoso
# 7   8vpj3b9v      Chloe    Juanico
# 8   rnse61g4      Chloe      Roman
# 9   wnprz3dq     Claire  Hemingway
# 10  oxcpr7e3       Chaz        Lee
# 11  t4jphih6     Collin         Ma
# 12  xxvnhauv      David    Koeller
# 13  hxj6brwj       Deni        Hui
# 14  xdbdrk6e      Diane        Bao
#
#                                           Address
# 0     1701 Brook Hollow Dr, Fort Worth, TX, 76114
# 1   2715 9th Street Wichita Falls, TX, 76301-3912
# 2     1301 Crossing Pl apt 1513, Austin, TX 78741
# 3                4918 Laurel St Bellaire TX 77401
# 4        3633 Aquamarine Dr. Round Rock, TX 78681
# 5   2822 Rio Grande St. Apt 202 Austin, TX, 78705
# 6        806 East High St. Grand Saline TX 75140
# 7       20106 Cypresswood Glen, Spring, TX, 77373
# 8         600 W. 26th St APT 3106 Austin TX 78705
# 9                  4606 Avenue F Austin, Tx 78751
# 10   1640 West 6th Street Apt.D, Austin, TX 78703
# 11        400 W 35th St. Apt 204 Austin, TX 78705
# 12          2518 Leon St Apt 315 Austin, TX 78705
# 13        1715 Guadalupe Street, Austin, TX 78701
# 14      780 River Oaks Drive, Fairview, TX, 75069

# %% [markdown]
# # Getting City and State
# We can take advantage of address format to pull out the state and city that participants live in.

# %%
def add_city_state(df):
    """
    Adds the city and the state to the given dataframe
    """
    # pre-allocating
    df["state"] = "TX"
    df["city"] = "Austin"
    df.reset_index() # precaution
    for i in range(len(df)):
        address = df.loc[i,"Address"]
        state = address.split(" ")[-2].replace(",","").replace(".","").upper()
        city = address.split(" ")[-3].replace(",","").replace(".","").upper()
        df.loc[i,"state"] = state
        df.loc[i,"city"] = city

    df.replace("TEXAS","TX",inplace=True)

# %%
add_city_state(info)
info
# Out:
#     Beiwe ID      First      Last  \
# 0   y1tvkx14      Aaron  Alterman
# 1   pgvvwyvh      Aaron     Wheat
# 2   idbkjh8u      Alana  Martinez
# 3   eyf8oqwl  Alexander      Chan
# 4   789gcb6u    Adriana    Banchs
# ..       ...        ...       ...
# 62  rjcs3hyw   Samantha       Liu
# 63  1adkek2h     Victor    Mwaura
# 64  y4m7yv2u      Megan     Ramos
# 65  naucsx6v      Alvin        Ta
# 66  bayw6h9b   Yuanting        Xu
#
#                                           Address state        city
# 0     1701 Brook Hollow Dr, Fort Worth, TX, 76114    TX       WORTH
# 1   2715 9th Street Wichita Falls, TX, 76301-3912    TX       FALLS
# 2     1301 Crossing Pl apt 1513, Austin, TX 78741    TX      AUSTIN
# 3                4918 Laurel St Bellaire TX 77401    TX    BELLAIRE
# 4        3633 Aquamarine Dr. Round Rock, TX 78681    TX        ROCK
# ..                                            ...   ...         ...
# 62             8125 Haning Drive  Plano, TX 75025    TX       PLANO
# 63            2830 lake rd, Huntsville, TX, 77340    TX  HUNTSVILLE
# 64       40 Newtown Ave North Kingstown, RI 02852    RI   KINGSTOWN
# 65              5716 Sabetha Way, Plano, TX 75094    TX       PLANO
# 66         14003 Kimberley Ln   Houston, TX 77079    TX     HOUSTON
#
# [67 rows x 6 columns]

# %% [markdown]
# # Looking at the Results

# %%
print("Number in Texas:", len(info[info['state'] == 'TX']))
print("Number in Austin:", len(info[info['city'] == 'AUSTIN']))
print("Number Out-of-State:", len(info[info['state'] != 'TX']))
# Out:
# Number in Texas: 65
# Number in Austin: 26
# Number Out-of-State: 2

# %% [markdown]
# # Address Change
# The addresses might have changed at some point during the study.

# %%
change = pd.read_excel("../data/raw/utx000/admin/s20c2_participant_list.xlsx",sheet_name="Kit Mailing")
change = change[["First","Last","Address"]]
change.head()
# Out:
#        First      Last                                         Address
# 0      Aaron  Alterman     1701 Brook Hollow Dr, Fort Worth, TX, 76114
# 1      Aaron     Wheat          305 E. 21st St. #I003 Austin, TX 78705
# 2      Alana  Martinez        911 W 21st St Apt 2507, Austin, TX 78705
# 3  Alexander      Chan  2529 Rio Grande Street Apt #89 Austin TX 78705
# 4     Angela  Gordillo        4605 Avenue A APT 214, Austin, TX, 78751

# %%
add_city_state(change)
comb = info.merge(right=change,on=["First","Last"],how="left",suffixes=["_start","_end"])
comb["moved"] = [True if s == e else False for s, e in zip(comb["city_start"], comb["city_end"])]
comb
# Out:
#     Beiwe ID      First      Last  \
# 0   y1tvkx14      Aaron  Alterman
# 1   pgvvwyvh      Aaron     Wheat
# 2   idbkjh8u      Alana  Martinez
# 3   eyf8oqwl  Alexander      Chan
# 4   789gcb6u    Adriana    Banchs
# ..       ...        ...       ...
# 63  rjcs3hyw   Samantha       Liu
# 64  1adkek2h     Victor    Mwaura
# 65  y4m7yv2u      Megan     Ramos
# 66  naucsx6v      Alvin        Ta
# 67  bayw6h9b   Yuanting        Xu
#
#                                     Address_start state_start  city_start  \
# 0     1701 Brook Hollow Dr, Fort Worth, TX, 76114          TX       WORTH
# 1   2715 9th Street Wichita Falls, TX, 76301-3912          TX       FALLS
# 2     1301 Crossing Pl apt 1513, Austin, TX 78741          TX      AUSTIN
# 3                4918 Laurel St Bellaire TX 77401          TX    BELLAIRE
# 4        3633 Aquamarine Dr. Round Rock, TX 78681          TX        ROCK
# ..                                            ...         ...         ...
# 63             8125 Haning Drive  Plano, TX 75025          TX       PLANO
# 64            2830 lake rd, Huntsville, TX, 77340          TX  HUNTSVILLE
# 65       40 Newtown Ave North Kingstown, RI 02852          RI   KINGSTOWN
# 66              5716 Sabetha Way, Plano, TX 75094          TX       PLANO
# 67         14003 Kimberley Ln   Houston, TX 77079          TX     HOUSTON
#
#                                        Address_end state_end city_end  moved
# 0      1701 Brook Hollow Dr, Fort Worth, TX, 76114        TX    WORTH   True
# 1           305 E. 21st St. #I003 Austin, TX 78705        TX   AUSTIN  False
# 2         911 W 21st St Apt 2507, Austin, TX 78705        TX   AUSTIN   True
# 3   2529 Rio Grande Street Apt #89 Austin TX 78705        TX   AUSTIN  False
# 4                                              NaN       NaN      NaN  False
# ..                                             ...       ...      ...    ...
# 63                                             NaN       NaN      NaN  False
# 64                                             NaN       NaN      NaN  False
# 65                                             NaN       NaN      NaN  False
# 66                                             NaN       NaN      NaN  False
# 67                                             NaN       NaN      NaN  False
#
# [68 rows x 10 columns]

# %%
to_save = comb.drop(["First","Last"],axis="columns").rename({"Beiwe ID":"beiwe","Address_start":"address_start","address_end":"address_end"},axis="columns")

# %%
to_save.to_csv("../data/raw/utx000/admin/participant_locations.csv")
